# %%
import sys
sys.path.append('../gSpan')
from gspan import gSpan
from use_gspan import read_gml_graphs

# %%
#standart case
gs = gSpan(
        database_file_name='C:\\Users\\N\\PycharmProjects\\edit_xls\\gSpan\\graphdata\\graph.data.5',
        min_support=2,
        min_num_vertices=2,
        max_num_vertices=float('inf'),
        max_ngraphs=float('inf'),
        is_undirected=1,
        verbose=0,
        visualize=0,
        where=0)

gs.run()
gs.time_stats()
gs.report_df.to_csv('gen/group.csv', sep=';')
gs.report_df
# Out:
# t # 0
# v 0 2
# v 1 6
# e 0 1 2
#
# Support: 3
#
# -----------------
#
# t # 1
# v 0 2
# v 1 6
# v 2 6
# e 0 1 2
# e 1 2 2
#
# Support: 2
#
# -----------------
#
# t # 2
# v 0 2
# v 1 6
# v 2 6
# v 3 2
# e 0 1 2
# e 1 2 2
# e 2 3 2
#
# Support: 2
#
# -----------------
#
# t # 3
# v 0 2
# v 1 6
# v 2 6
# v 3 2
# v 4 2
# e 0 1 2
# e 1 2 2
# e 2 3 2
# e 3 4 5
#
# Support: 2
#
# -----------------
#
# t # 4
# v 0 2
# v 1 6
# v 2 6
# v 3 2
# v 4 2
# v 5 2
# e 0 1 2
# e 1 2 2
# e 2 3 2
# e 3 4 5
# e 4 5 5
#
# Support: 2
#
# -----------------
#
# t # 5
# v 0 2
# v 1 6
# v 2 6
# v 3 2
# v 4 2
# v 5 2
# v 6 2
# e 0 1 2
# e 1 2 2
# e 2 3 2
# e 3 4 5
# e 4 5 5
# e 5 6 5
#
# Support: 2
#
# -----------------
#
# t # 6
# v 0 2
# v 1 6
# v 2 6
# v 3 2
# v 4 2
# v 5 2
# v 6 2
# v 7 2
# e 0 1 2
# e 1 2 2
# e 2 3 2
# e 3 4 5
# e 4 5 5
# e 5 6 5
# e 6 7 5
#
# Support: 2
#
# -----------------
#
# t # 7
# v 0 2
# v 1 6
# v 2 6
# v 3 2
# v 4 2
# v 5 2
# v 6 2
# v 7 2
# v 8 2
# e 0 1 2
# e 1 2 2
# e 2 3 2
# ...

# %%
gs = gSpan(
        database_file_name='C:\\Users\\N\\PycharmProjects\\edit_xls\\gSpan\\graphdata\\graph.data.5',
        min_support=200,
        min_num_vertices=2,
        max_num_vertices=float('inf'),
        max_ngraphs=float('inf'),
        is_undirected=1,
        verbose=0,
        visualize=0,
        where=0)

# %%
group_id=0
gs.graphs=read_gml_graphs('C:\\Users\\N\\PycharmProjects\\edit_xls\\with_tags',group_id=0)
gs.run()
gs.time_stats()
gs.report_df.to_csv('gen/group_'+str(group_id)+'_s'+str(gs.min_support)+'_l'+str(gs.min_num_vertices)+'.csv', sep=';')

# %%
######Add some report info to pandas dataframe "self.report_df"#####
max_eg=max([tupl[0] for tupl in g.set_of_elb[1]])
self.report_df=self.report_df.append(pd.DataFrame(
{'support':[self.support],
'description':[display_str],
'num_vert':self.DFScode.get_num_vertices(),
'max_eg_vert': max_eg,},

# %%
df.to_csv('c:/group_'+str(0)+'_s'+str(gs.min_support)+'_l'+str(2)+'.csv', sep=';')

# %%
with open('./out.csv', 'w') as f:
    p=df.to_csv(f, sep=';')

# %%
import pandas as pd
df=pd.read_csv('../with_tags/batch_1-50_files/5-Ким-comm_inosmi_73_233712.csv', sep=';', encoding='cp1251' )
df
# Out:
#     Unnamed: 0  Unnamed: 0.1  Id of comment.  Id of author of comment.  \
# 0         7991         38108          233713                 139785506
# 1         7992         38109          233714                 287804305
# 2         7993         38110          233715                    507657
# 3         7994         38111          233716                 305929871
# 4         7995         38112          233717                  20124385
# 5         7996         38113          233718                  20359088
# 6         7997         38114          233719                 252652514
# 7         7998         38115          233720                  20359088
# 8         7999         38116          233721                   2732653
# 9         8000         38117          233722                 297890260
# 10        8001         38118          233723                 297890260
# 11        8002         38119          233736                 167644740
# ...

# %%
df.to_csv('out1.csv', sep='\t', encoding='utf-8')
