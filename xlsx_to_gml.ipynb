# %%
! ls drive/Проверено/не_проверено/Плотникова_кодКудрявцевой/
# Out:
# 25106701_426555.xlsx  25106701_427233.xlsx  25106701_441947.xlsx
# 25106701_426866.xlsx  25106701_427837.xlsx  25106701_441985.xlsx
# 25106701_426881.xlsx  25106701_427941.xlsx
# 25106701_427082.xlsx  25106701_441528.xlsx

# %%
! pip install python-igraph
! pip install xlrd
# Out:
# Collecting python-igraph
#   Downloading https://files.pythonhosted.org/packages/0f/a0/4e7134f803737aa6eebb4e5250565ace0e2599659e22be7f7eba520ff017/python-igraph-0.7.1.post6.tar.gz (377kB)
#     100% |████████████████████████████████| 378kB 5.0MB/s
# Building wheels for collected packages: python-igraph
# done
#   Stored in directory: /content/.cache/pip/wheels/41/d6/02/34eebae97e25f5b87d60f4c0687e00523e3f244fa41bc3f4a7
# Successfully built python-igraph
# Installing collected packages: python-igraph
# Successfully installed python-igraph-0.7.1.post6
# Collecting xlrd
#   Downloading https://files.pythonhosted.org/packages/07/e6/e95c4eec6221bfd8528bcc4ea252a850bffcc4be88ebc367e23a1a84b0bb/xlrd-1.1.0-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 2.5MB/s
# Installing collected packages: xlrd
# Successfully installed xlrd-1.1.0

# %%
import pandas as pd
import math
import numpy as np
import igraph

def xlsx_to_gml(filename):
    #read xlsx file into dataframe
    post_df = pd.read_excel(filename)
    #list to add comment ids that were deleted for some reason
    met_id = list()

    for comment in post_df.iterrows():
        if ( (not math.isnan(comment[1]['reply_to_comment'])) and 
            (comment[1]['reply_to_comment'] not in met_id) and
            (comment[1]['reply_to_comment'] not in post_df['id'].tolist()) ):
                met_id.append(comment[1]['reply_to_comment'])
                
    
    met_id_df = pd.DataFrame({'id' : met_id})
    print(len(met_id_df))
    print(len(post_df))
    #adding empty rows with id field so that every comment id mentioned in xlsx gets its node.
    post_df = pd.concat([post_df,met_id_df],ignore_index=True)
    print(len(post_df))
    #creating a root node
    root = {'id' : filename[len(filename)-11:len(filename)-5]}
    print(root)
    root_df = pd.DataFrame(root,index = ['0'])
    print(root_df)
    
    
    post_df = pd.concat([root_df,post_df],ignore_index=True)
    print(post_df.loc[0])
    post_Graph = igraph.Graph(directed=True)
    post_Graph.add_vertices(len(post_df)) #all comments get a node + root node for the post itself

    post_Graph.vs['attachments'] = post_df['attachments'].fillna('').apply(str).tolist()
    post_Graph.vs['date'] = post_df['date'].fillna('').apply(str).tolist()
    post_Graph.vs['from_id'] = post_df['from_id'].fillna('').apply(str).tolist()
    post_Graph.vs['comment_id'] = post_df['id'].fillna('').apply(str).tolist()
    post_Graph.vs['reply_to_comment'] = post_df['reply_to_comment'].fillna('').apply(str).tolist()
    post_Graph.vs['reply_to_user'] = post_df['reply_to_user'].fillna('').apply(str).tolist()
    post_Graph.vs['text'] = post_df['text'].fillna('').apply(str).tolist()
    post_Graph.vs['intent'] = post_df['Intent'].fillna('').apply(str).tolist()
    post_Graph.vs['content'] = post_df['Content'].fillna('').apply(str).tolist()
    post_Graph.vs['intervention'] = post_df['Intervention'].fillna('').apply(str).tolist()
    
    for comment in post_df.iterrows():
        if ( (math.isnan(comment[1]['reply_to_comment']))):
            post_Graph.add_edge(0,comment[0])
            print('Added an edge between root and ' + str(comment[0]) + ' vertice ')
        else:
            for replied_comment in post_df.iterrows():
                if (replied_comment[1]['id'] == comment[1]['reply_to_comment']):
                    post_Graph.add_edge(replied_comment[0], comment[0])
    
    
    post_Graph.write_gml(filename[:6] + 'gml from excel' + filename[15:len(filename)-5] + '.gml')            
        
xlsx_to_gml('drive/Проверено/Проверено_Плотниковой/Набокова_кодКудрявцевой_провереноПлотниковой/25106701_437584.xlsx')
# Out:
# 0
# 41
# 41
# {'id': '437584'}
#        id
# 0  437584
# Content                NaN
# Intent                 NaN
# Intervention           NaN
# attachments            NaN
# date                   NaN
# from_id                NaN
# id                  437584
# reply_to_comment       NaN
# reply_to_user          NaN
# text                   NaN
# Name: 0, dtype: object
# Added an edge between root and 0 vertice
# Added an edge between root and 1 vertice
# Added an edge between root and 2 vertice
# Added an edge between root and 6 vertice
# Added an edge between root and 12 vertice
# Added an edge between root and 19 vertice
# Added an edge between root and 20 vertice
# Added an edge between root and 22 vertice
# Added an edge between root and 23 vertice
# Added an edge between root and 24 vertice
# Added an edge between root and 27 vertice
# Added an edge between root and 28 vertice
# Added an edge between root and 29 vertice
# Added an edge between root and 30 vertice
# Added an edge between root and 36 vertice

# %%
# Out:
# {'post_id': '437584'}
#   post_id
# 0  437584
# <class 'pandas.core.series.Series'>
# Added an edge between root and 2 vertice
# Added an edge between root and 3 vertice
# Added an edge between root and 4 vertice
# Added an edge between root and 8 vertice
# Added an edge between root and 14 vertice
# Added an edge between root and 21 vertice
# Added an edge between root and 22 vertice
# Added an edge between root and 24 vertice
# Added an edge between root and 25 vertice
# Added an edge between root and 26 vertice
# Added an edge between root and 29 vertice
# Added an edge between root and 30 vertice
# Added an edge between root and 31 vertice
# Added an edge between root and 32 vertice
# Added an edge between root and 38 vertice
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: A non-numeric, non-string, non-boolean edge attribute was ignored at foreign.c:2648

# %%
import pandas as pd
import numpy as np
kek_list = list()
kek_list.append('45')
kek_list.append('42352342')

kek_df = pd.DataFrame({'id' : kek_list})
data = np.array([np.arange(10)+1]*3).T
topkek_df = pd.DataFrame(data, columns = ['id','name','intent'])
topkek_df = topkek_df.append(kek_df, ignore_index = True)
len(topkek_df)
# Out:
# 12

# %%
# Install requirements 
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

# Connect
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
post_df = pd.read_excel('drive/Проверено/Проверено_Плотниковой/Набокова_кодКудрявцевой_провереноПлотниковой/25106701_437584.xlsx')
post_df
# Out:
#                                           attachments        date    from_id  \
# 0                                                 NaN  1503108562    7589512
# 1                                                 NaN  1503108590   46701659
# 2                                                 NaN  1503108653   46701659
# 3                                                 NaN  1503109899  376816938
# 4                                                 NaN  1503109983  376816938
# 5   [{'type': 'video', 'video': {'id': 456239355, ...  1503110346    8446077
# 6                                                 NaN  1503111274   46701659
# 7                                                 NaN  1503111442  376816938
# 8                                                 NaN  1503113344  172064826
# 9                                                 NaN  1503114528  376816938
# 10                                                NaN  1503115266  172064826
# 11                                                NaN  1503116291  376816938
# 12                                                NaN  1503116796  172064826
# 13                                                NaN  1503116853  376816938
# 14                                                NaN  1503117134  172064826
# 15                                                NaN  1503117210  376816938
# 16                                                NaN  1503119818  195361860
# 17                                                NaN  1503119971     910323
# 18                                                NaN  1503120441  376816938
# 19                                                NaN  1503121967  341909012
# 20                                                NaN  1503126161    7505788
# 21                                                NaN  1503133370  370722155
# 22                                                NaN  1503134267  139685782
# 23  [{'type': 'link', 'link': {'url': 'http://maxp...  1503146721  288973843
# 24                                                NaN  1503147346   46701659
# 25                                                NaN  1503147488   46701659
# 26                                                NaN  1503153462   12367434
# 27                                                NaN  1503166982  322152172
# 28                                                NaN  1503167838  437072715
# 29                                                NaN  1503177514  212488009
# 30                                                NaN  1503179051  437072715
# 31                                                NaN  1503273002  212488009
# 32                                                NaN  1503429006  437072715
# 33                                                NaN  1503440337  212488009
# 34                                                NaN  1503441793  212488009
# 35                                                NaN  1503442197  212488009
# 36                                                NaN  1503515219  437072715
# 37                                                NaN  1503527971  212488009
# 38                                                NaN  1503599398  437072715
# 39                                                NaN  1503610033  212488009
# 40                                                NaN  1503688723  437072715
#
#         id  reply_to_comment  reply_to_user  \
# 0   437585               NaN            NaN
# 1   437586               NaN            NaN
# 2   437587          437585.0      7589512.0
# 3   437588          437587.0     46701659.0
# 4   437589          437587.0     46701659.0
# 5   437590               NaN            NaN
# 6   437591          437588.0    376816938.0
# 7   437592          437591.0     46701659.0
# 8   437597          437589.0    376816938.0
# 9   437601          437597.0    172064826.0
# 10  437602          437601.0    376816938.0
# 11  437603               NaN            NaN
# 12  437604          437603.0    376816938.0
# 13  437605          437604.0    172064826.0
# 14  437606          437605.0    376816938.0
# 15  437608          437606.0    172064826.0
# 16  437610          437587.0     46701659.0
# 17  437611          437608.0    376816938.0
# 18  437612               NaN            NaN
# 19  437615               NaN            NaN
# 20  437621          437612.0    376816938.0
# 21  437626               NaN            NaN
# 22  437628               NaN            NaN
# 23  437662               NaN            NaN
# 24  437663          437603.0    376816938.0
# 25  437665          437605.0    376816938.0
# 26  437667               NaN            NaN
# 27  437692               NaN            NaN
# 28  437694               NaN            NaN
# 29  437702               NaN            NaN
# 30  437705          437702.0    212488009.0
# 31  437790          437705.0    437072715.0
# 32  438393          437790.0    212488009.0
# 33  438430          438393.0    437072715.0
# 34  438431          438393.0    437072715.0
# 35  438432               NaN            NaN
# 36  438644          438432.0    212488009.0
# 37  438662          438644.0    437072715.0
# 38  438912          438662.0    212488009.0
# 39  438967          438912.0    437072715.0
# 40  439235          438967.0    212488009.0
#
#                                                  text  Intent  Content  \
# 0   Да уж с этим не прокатит типа денег нет но вы ...      Ш4        2
# 1                          Без Путина, Кадыров никто.      Ж4        1
# 2   [id7589512|Максим], Чечня давно сама зарабатыв...  Б3, Х4        1
# 3                 [id46701659|Андрей], Интересно чем?      А3        2
# 4   [id46701659|Андрей], Зинданы просто в федераль...      Ж4        4
# 5   хотят Путина с Кадыровым поссорить )))\nдля не...      Ж4        0
# 6      [id376816938|Роман], нефть добывают, например.      Ж4        2
# 7   [id46701659|Андрей], А ты почитай для начала с...      Р3        3
# 8   [id376816938|Роман], много знаешь про эти самы...      Н3        3
# 9   [id172064826|Виталий], Много. Я виталий не отн...      Е1        4
# 10  [id376816938|Роман], а кто-то спорит , что в 9...      Ж3        4
# 11  ты дебулушка не понял аллегорию про зинданы. Я...  Л3, Ж4        3
# 12  Роман, ах значит простое балабольство ради бал...  Н3, Г3        4
# 13  [id172064826|Виталий], Ты просто олигофрен мал...     Л3         4
# 14  Я старше тебя , дурнина. \nА вот ты действител...      Ч3        4
# 15    [id172064826|Виталий], а мозгов не нажил. пока.  Н3, Г3        4
# 16  Поэтому дотации туда больше чем в любой другой...      А3        1
# 17  [id376816938|Роман], не обращай внимание на хо...      Р3        4
# 18  Александр, Да меня не хило так с утра взбесила...      К3        4
# 19  У западных журнашлюх очередной антироссийский ...      Н2        3
# 20  [id376816938|Роман], да денюшку чувак зарабаты...      Щ3        4
# 21  Ничего плохого не вижу в том, что Кадыров поль...      Х4        0
# 22  причем тут "союзник", если Чечня - это Россия,...      И4        1
# 23  И ещё - КАК СМОГ Собрал, До-Полнил (Думаю до К...      Ж4        4
# 24  [id376816938|Роман], это ты "недогражданин" , ...      Ч3        3
# 25  [id376816938|Роман], звание чёрта дано тебе не...      Н3        4
# 26                     Думаю тут зависимость взаимная      И4        0
# 27  Господи опять эти рассуждения никчемные, вы се...      Ч2        1
# 28  Рамзан - серьезный такой товарищ, и главное - ...      Х4        0
# 29  А вот рвущимся к власти либералам может не поз...      У4        1
# 30  [id212488009|Нелли], да, ребята хорошо подгото...      В3        2
# 31  [id437072715|Finest], В соответствии с приказо...      Ж4        3
# 32  [id212488009|Нелли], спасибо за так подробно р...  Х2, Х4        3
# 33  [id437072715|Finest], некоторым цивилизаторам ...      Ж4        4
# 34  [id437072715|Finest], Кто-то живет наукой, кто...      П4        4
# 35  Риторический вопрос\nЧитаю Дневник мусульманин...      Ж4        4
# 36         [id212488009|Нелли], это Вашего сочинения?      А3        4
# 37  [id437072715|Finest], yes...Иногда "накрывает"...      Е1        4
# 38  [id212488009|Нелли], Вы молодец! Глубокие расс...     Х2         4
# 39  [id437072715|Finest], все просто: возраст любв...      Д3        4
# 40  [id212488009|Нелли], спасибо большое, очень пр...      Д3        4
#
#    Intervention
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28            n
# 29          NaN
# 30            n
# 31          NaN
# 32            n
# 33          NaN
# 34          NaN
# 35          NaN
# 36            n
# 37          NaN
# 38            n
# 39          NaN
# 40            n

# %%
filename = ('drive/Проверено/Проверено_Плотниковой/Набокова_кодКудрявцевой_провереноПлотниковой/25106701_437584.xlsx')
filename = filename[len(filename)-11:len(filename)-5]
filename
# Out:
# '437584'
